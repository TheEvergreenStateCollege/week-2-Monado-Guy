# %% [markdown]
# <a href="https://colab.research.google.com/github/TheEvergreenStateCollege/week-2-Monado-Guy/blob/main/week-2-Monado-Guy/lab/lab10/choose_dataset_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

tips = sns.load_dataset("tips")

# %%
sns.lmplot(data = tips, x = "total_bill", y = "tip");

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.value_counts()
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       2
# 3.07        1.00   Female  Yes     Sat   Dinner  1       1
# 22.23       5.00   Male    No      Sun   Dinner  2       1
# 20.69       2.45   Female  No      Sat   Dinner  4       1
#             5.00   Male    No      Sun   Dinner  5       1
#                                                         ..
# 15.53       3.00   Male    Yes     Sat   Dinner  2       1
# 15.69       1.50   Male    Yes     Sun   Dinner  2       1
#             3.00   Male    Yes     Sat   Dinner  3       1
# 15.77       2.23   Female  No      Sat   Dinner  2       1
# 50.81       10.00  Male    Yes     Sat   Dinner  3       1
# Length: 243, dtype: int64

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.lmplot(data = tips, x = "total_bill", y = "tip", hue="sex")

# %%
x = tips["total_bill"]
y = tips["tip"]

mymodel = np.poly1d(np.polyfit(x, y, 5))

line = np.linspace(0, 50)

plt.scatter(x, y)
plt.plot(line, mymodel(line))
plt.show()
